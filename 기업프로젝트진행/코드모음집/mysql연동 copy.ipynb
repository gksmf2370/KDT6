# %%
import mysql.connector
import joblib
from datetime import datetime
import time
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor

# %%
conn = mysql.connector.connect(
    host = 'localhost',
    user ='root',
    password = '1234',
    database = 'bawel'
)
# 연결 확인
if conn.is_connected():
    print("MySQL에 성공적으로 연결되었습니다")
else:
    print("MySQL 연결 실패")
# Out:
# MySQL에 성공적으로 연결되었습니다

# %%
cursor = conn.cursor()

# %%
model = joblib.load('forest_model.pkl')

# %%
# 현재 시간 기준 데이터 가져오기
def fetch_data_by_current_time(cursor, current_time):
    query = """
    SELECT c_temp_pv, k_rpm_pv, n_temp_pv, s_temp_pv
    FROM linear_model
    WHERE timestamp = %s
    """
    cursor.execute(query, (current_time,))
    rows = cursor.fetchall()
    return rows

# %%
def save_prediction_to_db(cursor, prediction, timestamp):
    query = """
    INSERT INTO predictions (timestamp, predicted_scale_pv)
    VALUES (%s, %s)
    """
    cursor.execute(query, (timestamp, prediction))
    conn.commit()

# %%
try:
    while True:
        # 현재 시간 가져오기
        current_time = datetime.now().strftime('%Y-%m-%d %H:%M:%S')
        print(f"현재 시간: {current_time}")

        # 데이터 가져오기
        data = fetch_data_by_current_time(cursor, current_time)
        
        if data:  # 데이터가 있을 경우만 처리
            # 데이터를 numpy 배열로 변환
            X = np.array([row for row in data])  # 입력 데이터만 가져옴

            # 예측 수행
            prediction = model.predict(X)
            predicted_value = prediction[0]  # 첫 번째 예측값 사용 (배열 형태이므로 첫 값을 추출)

            print(f"예측된 scale_pv 값: {predicted_value}")

            # 예측 결과를 DB에 저장
            save_prediction_to_db(cursor, predicted_value, current_time)
        else:
            print("현재 시간에 해당하는 데이터가 없습니다.")

        # 1초 대기
        time.sleep(1)

except KeyboardInterrupt:
    print("실시간 처리를 중지합니다.")
finally:
    cursor.close()
    conn.close()
# Out:
# 현재 시간: 2024-11-26 10:57:42
# 예측된 scale_pv 값: 3.0399000000000016
# c:\Users\KDP15\anaconda3\envs\yesmate\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# 현재 시간: 2024-11-26 10:57:43
# 예측된 scale_pv 값: 3.0399000000000016
# c:\Users\KDP15\anaconda3\envs\yesmate\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# 현재 시간: 2024-11-26 10:57:44
# 예측된 scale_pv 값: 3.0415000000000014
# c:\Users\KDP15\anaconda3\envs\yesmate\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# 현재 시간: 2024-11-26 10:57:45
# 예측된 scale_pv 값: 3.0327950000000037
# ...
