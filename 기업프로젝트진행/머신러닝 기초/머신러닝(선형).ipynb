# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np 
import seaborn as sns

# %%
# 모델
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, RobustScaler, MinMaxScaler
from sklearn.metrics import mean_absolute_percentage_error, mean_absolute_error

# %%
data = pd.read_csv(r'C:\Users\KDP15\Desktop\KDT6\기업프로젝트진행\데이터셋\Linear_model(2.9~3.1).csv')

# %%
correlation_matrix = data.corr()
print(correlation_matrix)

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.show()
# Out:
#            c_temp_pv  k_rpm_pv  n_temp_pv  scale_pv  s_temp_pv
# c_temp_pv   1.000000  0.099981   0.043204 -0.032720  -0.014492
# k_rpm_pv    0.099981  1.000000  -0.302308 -0.164919  -0.265386
# n_temp_pv   0.043204 -0.302308   1.000000  0.248792   0.700483
# scale_pv   -0.032720 -0.164919   0.248792  1.000000   0.089202
# s_temp_pv  -0.014492 -0.265386   0.700483  0.089202   1.000000

# %%
X = data[['c_temp_pv','k_rpm_pv','n_temp_pv','s_temp_pv']]
y = data['scale_pv']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=77)

# %%
model =LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
print(model.score(X_train,y_train))
print(model.score(X_test,y_test))
# Out:
# 0.08684814449115563
# 0.09504355694121358

# %%
mae = mean_absolute_error(y_test, y_pred)
mape = mean_absolute_percentage_error(y_test, y_pred)

print(f"mae = {mae}")
print(f"mape = {mape*100}%")
print(f"R2 = {model.score(X_test,y_test)}")
# Out:
# mae = 0.004492524066664379
# mape = 0.14808110636750432%
# R2 = 0.09504355694121358
