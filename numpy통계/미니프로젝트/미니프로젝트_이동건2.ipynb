# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import koreanize_matplotlib

# %%
file_path = r'Whiskey.csv'

# %%
df = pd.read_csv(file_path, index_col =0)

# %%
df=df.iloc[:, 1:]

# %%
df
# Out:
#                                                 Name        Country  \
# 0          Jack Daniel’s Old No. 7 Tennessee Whiskey  United States
# 1                      Jack Daniel’s Tennessee Honey  United States
# 2     Jack Daniel’s Gentleman Jack Tennessee Whiskey  United States
# 3      Jack Daniel’s Tennessee Fire Flavored Whiskey  United States
# 4     Jack Daniel’s Tennessee Apple Flavored Whiskey  United States
# ...                                              ...            ...
# 4098            John Mcgil Gold Label Blended Whisky       Scotland
# 4099      Blair Athol 12 Year Old Scotch Single Cask       Scotland
# 4100                Glen Oak Aged 28 Year Old Scotch       Scotland
# 4101                   King William IV Scotch Whisky       Scotland
# 4102                 Whitmeyer’s Texas Peach Whiskey  United States
#
#                 Brand                          Categories Tasting Notes  ABV  \
# ...

# %%
japan_df=df[df['Country'] == 'Japan']

# %%
japan_df = japan_df.drop(['Volume', 'Tasting Notes', 'Base Ingredient'], axis=1)

# %%
japan_df
# Out:
#                                               Name Country        Brand  \
# 1248                  Nikka Whisky From The Barrel   Japan        Nikka
# 1249                     Nikka Coffey Grain Whisky   Japan        Nikka
# 1250                      Nikka Coffey Malt Whisky   Japan        Nikka
# 1251                     Nikka Taketsuru Pure Malt   Japan        Nikka
# 1252                                  Nikka Yoichi   Japan        Nikka
# ...                                            ...     ...          ...
# 3789                        Shinju Japanese Whisky   Japan       Shinju
# 3790  Yame Eight Goddesses Japanese Whisky 10 Year   Japan         Yame
# 3791                        Oni No Shitaburui Honj   Japan  Chiyomusubi
# 3792                       Kurokame Kankaku Shochu   Japan     Kurokame
# 3793                           Sabi Wasabi Whiskey   Japan         Sabi
#
#                     Categories    ABV  Years Aged  Rating  Rate Count   Price  \
# ...

# %%
japan_df.isna().sum()
# Out:
# Name            0
# Country         0
# Brand           0
# Categories      0
# ABV            10
# Years Aged     60
# Rating          0
# Rate Count      0
# Price           0
# Description    16
# dtype: int64

# %%
japan_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 86 entries, 1248 to 3793
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        86 non-null     object
#  1   Country     86 non-null     object
#  2   Brand       86 non-null     object
#  3   Categories  86 non-null     object
#  4   ABV         76 non-null     object
#  5   Rating      86 non-null     float64
#  6   Rate Count  86 non-null     int64
#  7   Price       86 non-null     object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 6.0+ KB

# %%
japan_df = japan_df.drop(['Years Aged', 'Description'], axis=1)

# %%
japan_df['Price'] = japan_df['Price'].replace('[\$,]', '', regex=True).astype(float)

# %%
correlation = japan_df['Price'].corr(japan_df['Rating'])

# %%
plt.figure(figsize=(10, 6))
sns.regplot(x='Price', y='Rating', data=japan_df, scatter_kws={'s':50}, line_kws={'color':'red'})
plt.title(f'상관계수: {round(correlation,2)}')
plt.xlabel('price ($)')
plt.ylabel('rating')

plt.show()

# %%
japan_df[japan_df['Price'] ==japan_df['Price'].max()]
# Out:
#                             Name Country         Brand  \
# 2333  Yamazaki Mizunara 18 Years   Japan  The Yamazaki
#
#                     Categories  ABV  Rating  Rate Count    Price
# 2333  Japanese Whisky, Whiskey  48%     5.0           1  3999.99

# %%
plt.figure(figsize=(10, 6))
plt.hist(japan_df['Price'], bins=20, color='blue')
plt.title('가격별 히스토그램')
plt.xlabel('Price ($)')
plt.show()

# %%
# Title_score와 Review_score의 분포 분석: 평균, 중앙값, 표준편차 계산
price_mean = np.mean(japan_df['Price'])
price_median = np.median(japan_df['Price'])
price_std = np.std(japan_df['Price'])

# %%
import numpy as np

# %%
print(f'평균 : {price_mean}')
print(f'중앙값 : {price_median}')
print(f'표준편차 : {price_std}')
# Out:
# 평균 : 223.31453488372097
# 중앙값 : 89.99
# 표준편차 : 557.5660097195228
