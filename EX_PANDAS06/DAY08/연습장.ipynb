# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
F_DATA=r'C:\Users\KDP15\Desktop\KDT6\EX_PANDAS06\DATA\시도별 전출입 인구수.xlsx'

# %%
dataDF=pd.read_excel(F_DATA)

# %%
dataDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 325 entries, 0 to 324
# Data columns (total 50 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   전출지별    18 non-null     object
#  1   전입지별    324 non-null    object
#  2   1970    325 non-null    object
#  3   1971    325 non-null    object
#  4   1972    325 non-null    object
#  5   1973    325 non-null    object
#  6   1974    325 non-null    object
#  7   1975    325 non-null    object
#  8   1976    325 non-null    object
#  9   1977    325 non-null    object
#  10  1978    325 non-null    object
#  11  1979    325 non-null    object
#  12  1980    325 non-null    object
#  13  1981    325 non-null    object
#  14  1982    325 non-null    object
#  15  1983    325 non-null    object
#  16  1984    322 non-null    object
#  17  1985    322 non-null    object
#  18  1986    322 non-null    object
#  19  1987    325 non-null    object
#  20  1988    325 non-null    object
# ...

# %%
dataDF.describe(include='all')
# Out:
#        전출지별 전입지별 1970 1971 1972 1973 1974 1975 1976 1977  ... 2008 2009 2010  \
# count    18  324  325  325  325  325  325  325  325  325  ...  325  325  325
# unique   18   18  146  146  146  146  145  146  146  146  ...  289  289  289
# top      전국   전국    -    -    -    -    -    -    -    -  ...    -    -    -
# freq      1   18  180  180  180  180  180  180  180  180  ...   35   35   35
#
#        2011  2012  2013  2014  2015  2016 2017
# count   325   325   325   325   325   325  325
# unique  291   323   320   321   324   322  323
# top       -  1489  1939  2026  1468  4303  947
# freq     35     2     2     2     2     2    2
#
# [4 rows x 50 columns]

# %%
dataDF.head()
# Out:
#   전출지별   전입지별      1970      1971      1972      1973      1974      1975  \
# 0  NaN    NaN  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)
# 1   전국     전국   4046536   4210164   3687938   4860418   5297969   9011440
# 2  NaN  서울특별시   1742813   1671705   1349333   1831858   2050392   3396662
# 3  NaN  부산광역시    448577    389797    362202    482061    680984    805979
# 4  NaN  대구광역시         -         -         -         -         -         -
#
#        1976      1977  ...      2008      2009      2010      2011      2012  \
# 0  이동자수 (명)  이동자수 (명)  ...  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)
# 1   6773250   7397623  ...   8808256   8487275   8226594   8127195   7506691
# 2   2756510   2893403  ...   2025358   1873188   1733015   1721748   1555281
# 3    724664    785117  ...    514502    519310    519334    508043    461042
# 4         -         -  ...    409938    398626    370817    370563    348642
#
#        2013      2014      2015      2016      2017
# ...

# %%
copyDF=dataDF.drop(index=0)

# %%
copyDF.isna().sum()
# Out:
# 전출지별    306
# 전입지별      0
# 1970      0
# 1971      0
# 1972      0
# 1973      0
# 1974      0
# 1975      0
# 1976      0
# 1977      0
# 1978      0
# 1979      0
# 1980      0
# 1981      0
# 1982      0
# 1983      0
# 1984      3
# 1985      3
# 1986      3
# 1987      0
# 1988      0
# 1989      0
# 1990      0
# 1991      0
# 1992      0
# 1993      0
# 1994      0
# 1995      0
# 1996      0
# 1997      0
# 1998      0
# 1999      0
# 2000      0
# 2001      0
# 2002      0
# 2003      0
# 2004      0
# 2005      0
# 2006      0
# 2007      0
# 2008      0
# 2009      0
# 2010      0
# 2011      0
# 2012      0
# 2013      0
# 2014      0
# 2015      0
# 2016      0
# 2017      0
# dtype: int64

# %%
a=copyDF[['1984','1985','1986']].isna()
a[a.sum(axis=1)>0]
# Out:
#     1984  1985  1986
# 34  True  True  True
# 35  True  True  True
# 36  True  True  True

# %%
copyDF['전출지별']=copyDF['전출지별'].ffill()

# %%
copyDF=copyDF.fillna(0)
# Out:
# C:\Users\KDP15\AppData\Local\Temp\ipykernel_3600\4062627082.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   copyDF=copyDF.fillna(0)

# %%
copyDF.isna().sum()
# Out:
# 전출지별    0
# 전입지별    0
# 1970    0
# 1971    0
# 1972    0
# 1973    0
# 1974    0
# 1975    0
# 1976    0
# 1977    0
# 1978    0
# 1979    0
# 1980    0
# 1981    0
# 1982    0
# 1983    0
# 1984    0
# 1985    0
# 1986    0
# 1987    0
# 1988    0
# 1989    0
# 1990    0
# 1991    0
# 1992    0
# 1993    0
# 1994    0
# 1995    0
# 1996    0
# 1997    0
# 1998    0
# 1999    0
# 2000    0
# 2001    0
# 2002    0
# 2003    0
# 2004    0
# 2005    0
# 2006    0
# 2007    0
# 2008    0
# 2009    0
# 2010    0
# 2011    0
# 2012    0
# 2013    0
# 2014    0
# 2015    0
# 2016    0
# 2017    0
# dtype: int64

# %%
copyDF.replace('-', 0, inplace=True)
# Out:
# C:\Users\KDP15\AppData\Local\Temp\ipykernel_3600\1094950468.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   copyDF.replace('-', 0, inplace=True)

# %%
copyDF.shape
# Out:
# (324, 50)

# %%
d_ = dict(zip(copyDF.columns[2:].to_list(), ['int']*(copyDF.shape[1]-2)))
print(d_)
copyDF=copyDF.astype(d_)
# Out:
# {'1970': 'int', '1971': 'int', '1972': 'int', '1973': 'int', '1974': 'int', '1975': 'int', '1976': 'int', '1977': 'int', '1978': 'int', '1979': 'int', '1980': 'int', '1981': 'int', '1982': 'int', '1983': 'int', '1984': 'int', '1985': 'int', '1986': 'int', '1987': 'int', '1988': 'int', '1989': 'int', '1990': 'int', '1991': 'int', '1992': 'int', '1993': 'int', '1994': 'int', '1995': 'int', '1996': 'int', '1997': 'int', '1998': 'int', '1999': 'int', '2000': 'int', '2001': 'int', '2002': 'int', '2003': 'int', '2004': 'int', '2005': 'int', '2006': 'int', '2007': 'int', '2008': 'int', '2009': 'int', '2010': 'int', '2011': 'int', '2012': 'int', '2013': 'int', '2014': 'int', '2015': 'int', '2016': 'int', '2017': 'int'}

# %%
print(f'copyDF.dtypes\n {copyDF.dtypes}')
# Out:
# copyDF.dtypes
#  전출지별    object
# 전입지별    object
# 1970     int32
# 1971     int32
# 1972     int32
# 1973     int32
# 1974     int32
# 1975     int32
# 1976     int32
# 1977     int32
# 1978     int32
# 1979     int32
# 1980     int32
# 1981     int32
# 1982     int32
# 1983     int32
# 1984     int32
# 1985     int32
# 1986     int32
# 1987     int32
# 1988     int32
# 1989     int32
# 1990     int32
# 1991     int32
# 1992     int32
# 1993     int32
# 1994     int32
# 1995     int32
# 1996     int32
# 1997     int32
# 1998     int32
# 1999     int32
# 2000     int32
# 2001     int32
# 2002     int32
# 2003     int32
# 2004     int32
# 2005     int32
# 2006     int32
# 2007     int32
# 2008     int32
# 2009     int32
# 2010     int32
# 2011     int32
# 2012     int32
# 2013     int32
# 2014     int32
# 2015     int32
# 2016     int32
# 2017     int32
# dtype: object

# %%
mask = (copyDF['전출지별']=='대구광역시')
cityDF=copyDF[mask]
cityDF
# Out:
#      전출지별     전입지별  1970  1971  1972  1973  1974  1975  1976  1977  ...  \
# 55  대구광역시       전국     0     0     0     0     0     0     0     0  ...
# 56  대구광역시    서울특별시     0     0     0     0     0     0     0     0  ...
# 57  대구광역시    부산광역시     0     0     0     0     0     0     0     0  ...
# 58  대구광역시    대구광역시     0     0     0     0     0     0     0     0  ...
# 59  대구광역시    인천광역시     0     0     0     0     0     0     0     0  ...
# 60  대구광역시    광주광역시     0     0     0     0     0     0     0     0  ...
# 61  대구광역시    대전광역시     0     0     0     0     0     0     0     0  ...
# 62  대구광역시    울산광역시     0     0     0     0     0     0     0     0  ...
# 63  대구광역시  세종특별자치시     0     0     0     0     0     0     0     0  ...
# 64  대구광역시      경기도     0     0     0     0     0     0     0     0  ...
# 65  대구광역시      강원도     0     0     0     0     0     0     0     0  ...
# 66  대구광역시     충청북도     0     0     0     0     0     0     0     0  ...
# ...

# %%
cityDF=cityDF.drop('전출지별', axis=1)

# %%
cityDF.set_index('전입지별', inplace=True)

# %%
cityDF.drop(['대구광역시', '전국'], inplace=True)

# %%
print(cityDF.dtypes)
# Out:
# 1970    int32
# 1971    int32
# 1972    int32
# 1973    int32
# 1974    int32
# 1975    int32
# 1976    int32
# 1977    int32
# 1978    int32
# 1979    int32
# 1980    int32
# 1981    int32
# 1982    int32
# 1983    int32
# 1984    int32
# 1985    int32
# 1986    int32
# 1987    int32
# 1988    int32
# 1989    int32
# 1990    int32
# 1991    int32
# 1992    int32
# 1993    int32
# 1994    int32
# 1995    int32
# 1996    int32
# 1997    int32
# 1998    int32
# 1999    int32
# 2000    int32
# 2001    int32
# 2002    int32
# 2003    int32
# 2004    int32
# 2005    int32
# 2006    int32
# 2007    int32
# 2008    int32
# 2009    int32
# 2010    int32
# 2011    int32
# 2012    int32
# 2013    int32
# 2014    int32
# 2015    int32
# 2016    int32
# 2017    int32
# dtype: object

# %%
cityDF.columns
# Out:
# Index(['1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978',
#        '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987',
#        '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996',
#        '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005',
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
#        '2015', '2016', '2017'],
#       dtype='object')

# %%
cityDF.index
# Out:
# Index(['서울특별시', '부산광역시', '인천광역시', '광주광역시', '대전광역시', '울산광역시', '세종특별자치시', '경기도',
#        '강원도', '충청북도', '충청남도', '전라북도', '전라남도', '경상북도', '경상남도', '제주특별자치도'],
#       dtype='object', name='전입지별')

# %%
ToTalDF=cityDF.sum(axis=1)
ToTalDF.index
# Out:
# Index(['서울특별시', '부산광역시', '인천광역시', '광주광역시', '대전광역시', '울산광역시', '세종특별자치시', '경기도',
#        '강원도', '충청북도', '충청남도', '전라북도', '전라남도', '경상북도', '경상남도', '제주특별자치도'],
#       dtype='object', name='전입지별')

# %%
ToTalDF[:7]
# Out:
# 전입지별
# 서울특별시      638316
# 부산광역시      258658
# 인천광역시       77043
# 광주광역시       18531
# 대전광역시       65964
# 울산광역시       78498
# 세종특별자치시      3368
# dtype: int64

# %%
# 한글폰트 사용
import df_set_customFont as Fot
Fot.set_customFont('C:\Windows\Fonts\malgun.ttf')

from matplotlib.ticker import FuncFormatter

# %%
fig=plt.figure(figsize=(12,10))
ax1, ax2=fig.subplots(1,2, sharey=True)

ax1.plot(ToTalDF[:7])
import numpy as np
ax1.set_xticks(np.arange(0,7,1), ToTalDF.index[:7].to_list(),rotation=45)

ax2.bar(ToTalDF.index[:7].to_list(), ToTalDF[:7])
ax2.set_xticks(np.arange(0,7,1), ToTalDF.index[:7],rotation=45)

fig.suptitle('[대구광역시 => 타광역시 이동인구]', fontsize=20)
plt.show()

# %%
fig=plt.figure(figsize=(12,10))
ax1, ax2=fig.subplots(1,2, sharey=True)

ax1.plot(ToTalDF[7:])
import numpy as np
ax1.set_xticks(np.arange(0,7,1), ToTalDF.index[:7].to_list(),rotation=45)

ax2.bar(ToTalDF.index[7:].to_list(), ToTalDF[7:])
ax2.set_xticks(np.arange(0,9,1), ToTalDF.index[7:],rotation=45)

fig.suptitle('[대구광역시 => 타광역시 이동인구]', fontsize=20)
plt.show()

# %%
# - 데이터 추출
moveTotalDF=cityDF.sum()
print(moveTotalDF)
# Out:
# 1970         0
# 1971         0
# 1972         0
# 1973         0
# 1974         0
# 1975         0
# 1976         0
# 1977         0
# 1978         0
# 1979         0
# 1980         0
# 1981    132968
# 1982    127314
# 1983    144157
# 1984    134281
# 1985    133588
# 1986    130193
# 1987    140249
# 1988    140682
# 1989    129478
# 1990    140566
# 1991    133762
# 1992    125775
# 1993    123446
# 1994    113046
# 1995    115514
# 1996    131655
# 1997    123533
# 1998    118951
# 1999    123498
# 2000    113489
# 2001    117983
# 2002    117693
# 2003    118564
# 2004    116058
# 2005    127843
# 2006    128107
# 2007    118529
# 2008    111563
# 2009    112533
# 2010    108008
# 2011    106815
# 2012    104545
# 2013    105117
# 2014    113097
# 2015    105179
# 2016     96766
# 2017     96975
# dtype: int64

# %%
type(ToTalDF.index)
# Out:
# pandas.core.indexes.base.Index

# %%
def drawGraphe():
    fig=plt.figure(figsize=(12,10))
    ax1, ax2=fig.subplots(2,1, sharex=True)

    ax1.plot(moveTotalDF)
    ax2.bar(moveTotalDF.index.to_list(),moveTotalDF)

    fig.suptitle('[대구광역시 ==> 타도 이동인구수]', fontsize=20)
    plt.show()

# %%
drawGraphe()
